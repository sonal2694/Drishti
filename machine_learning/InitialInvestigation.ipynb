# %%
import pandas as pd

# %%
acled_india = pd.read_csv("./data/2016-01-01-2019-03-05-India.csv")

# %%
acled_india.describe()
# Out:
#             data_id      iso  event_id_no_cnty          year  time_precision  \
# count  4.372000e+04  43720.0      43720.000000  43720.000000    43720.000000
# mean   2.273510e+06    356.0      23419.192887   2017.266125        1.048285
# std    4.397306e+05      0.0      13580.803489      0.958775        0.227919
# min    1.758481e+06    356.0          1.000000   2016.000000        1.000000
# 25%    2.016902e+06    356.0      11684.750000   2016.000000        1.000000
# 50%    2.028040e+06    356.0      23341.500000   2017.000000        1.000000
# 75%    2.566829e+06    356.0      35260.250000   2018.000000        1.000000
# max    3.213293e+06    356.0      46888.000000   2019.000000        3.000000
#
#              inter1        inter2   interaction      latitude     longitude  \
# count  43720.000000  43720.000000  43720.000000  43720.000000  43720.000000
# mean       5.692658      0.825801     52.311825     25.231078     79.555633
# ...

# %%
acled_india.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty        event_date  year  \
# 0  3204471  356      IND46879           46879.0  23 February 2019  2019
# 1  3204472  356      IND46880           46880.0  23 February 2019  2019
# 2  3204473  356      IND46881           46881.0  23 February 2019  2019
# 3  3204474  356      IND46882           46882.0  23 February 2019  2019
# 4  3204475  356      IND46883           46883.0  23 February 2019  2019
#
#    time_precision      event_type              actor1  \
# 0               1  Riots/Protests  Protesters (India)
# 1               1  Riots/Protests     Rioters (India)
# 2               1  Riots/Protests     Rioters (India)
# 3               1  Riots/Protests  Protesters (India)
# 4               1  Riots/Protests  Protesters (India)
#
#                                        assoc_actor_1 ...      location  \
# 0                      INC: Indian National Congress ...       Cuttack
# ...
